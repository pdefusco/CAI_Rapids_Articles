# %%
# !pip install \
    --extra-index-url=https://pypi.nvidia.com \
    "cudf-cu12==24.12.*" "dask-cudf-cu12==24.12.*" "cuml-cu12==24.12.*" \
    "cugraph-cu12==24.12.*" "nx-cugraph-cu12==24.12.*" "cuspatial-cu12==24.12.*" \
    "cuproj-cu12==24.12.*" "cuxfilter-cu12==24.12.*" "cucim-cu12==24.12.*" \
    "pylibraft-cu12==24.12.*" "raft-dask-cu12==24.12.*" "cuvs-cu12==24.12.*" \
    "nx-cugraph-cu12==24.12.*"
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.nvidia.com
# Collecting cudf-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cudf-cu12/cudf_cu12-24.12.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (26.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 189.5 MB/s eta 0:00:00
# Collecting dask-cudf-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/dask-cudf-cu12/dask_cudf_cu12-24.12.0-py3-none-any.whl (67 kB)
# Collecting cuml-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cuml-cu12/cuml_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (548.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.0/548.0 MB 186.1 MB/s eta 0:00:0000:0100:01
# Collecting cugraph-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cugraph-cu12/cugraph_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (920.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 920.1/920.1 MB 228.4 MB/s eta 0:00:00a 0:00:01
# Collecting nx-cugraph-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/nx-cugraph-cu12/nx_cugraph_cu12-24.12.0-py3-none-any.whl (152 kB)
# Collecting cuspatial-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cuspatial-cu12/cuspatial_cu12-24.12.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (5.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 343.7 MB/s eta 0:00:00
# Collecting cuproj-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cuproj-cu12/cuproj_cu12-24.12.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (915 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 915.5/915.5 kB 419.1 MB/s eta 0:00:00
# Collecting cuxfilter-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cuxfilter-cu12/cuxfilter_cu12-24.12.0-py3-none-any.whl (83 kB)
# Collecting cucim-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cucim-cu12/cucim_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 306.4 MB/s eta 0:00:00
# Collecting pylibraft-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/pylibraft-cu12/pylibraft_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 287.5 MB/s eta 0:00:00
# Collecting raft-dask-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/raft-dask-cu12/raft_dask_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (196.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.9/196.9 MB 240.1 MB/s eta 0:00:0000:0100:01
# Collecting cuvs-cu12==24.12.*
#   Downloading https://pypi.nvidia.com/cuvs-cu12/cuvs_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (849.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.7/849.7 MB 262.8 MB/s eta 0:00:0000:0100:01
# Collecting cachetools (from cudf-cu12==24.12.*)
#   Downloading cachetools-5.5.1-py3-none-any.whl.metadata (5.4 kB)
# Collecting cuda-python<13.0a0,<=12.6.0,>=12.0 (from cudf-cu12==24.12.*)
#   Downloading cuda_python-12.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting cupy-cuda12x>=12.0.0 (from cudf-cu12==24.12.*)
#   Downloading cupy_cuda12x-13.3.0-cp310-cp310-manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: fsspec>=0.6.0 in /usr/local/lib/python3.10/site-packages (from cudf-cu12==24.12.*) (2024.3.1)
# Collecting libcudf-cu12==24.12.* (from cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/libcudf-cu12/libcudf_cu12-24.12.0-py3-none-manylinux_2_28_x86_64.whl (457.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 457.8/457.8 MB 273.1 MB/s eta 0:00:00a 0:00:01
# Collecting numba-cuda<0.0.18,>=0.0.13 (from cudf-cu12==24.12.*)
#   Downloading numba_cuda-0.0.17.1-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: numpy<3.0a0,>=1.23 in /usr/local/lib/python3.10/site-packages (from cudf-cu12==24.12.*) (1.26.4)
# Collecting nvtx>=0.2.1 (from cudf-cu12==24.12.*)
#   Downloading nvtx-0.2.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (740 bytes)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/site-packages (from cudf-cu12==24.12.*) (23.2)
# Requirement already satisfied: pandas<2.2.4dev0,>=2.0 in /usr/local/lib/python3.10/site-packages (from cudf-cu12==24.12.*) (2.1.4)
# Collecting pyarrow<19.0.0a0,>=14.0.0 (from cudf-cu12==24.12.*)
#   Downloading pyarrow-18.1.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Collecting pylibcudf-cu12==24.12.* (from cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/pylibcudf-cu12/pylibcudf_cu12-24.12.0-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 281.0 MB/s eta 0:00:00
# Collecting pynvjitlink-cu12 (from cudf-cu12==24.12.*)
#   Downloading pynvjitlink_cu12-0.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.5 kB)
# Collecting rich (from cudf-cu12==24.12.*)
#   Downloading rich-13.9.4-py3-none-any.whl.metadata (18 kB)
# Collecting rmm-cu12==24.12.* (from cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/rmm-cu12/rmm_cu12-24.12.1-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 441.2 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0.0 in /usr/local/lib/python3.10/site-packages (from cudf-cu12==24.12.*) (4.12.2)
# Collecting pynvml<12.0.0a0,>=11.4.1 (from dask-cudf-cu12==24.12.*)
#   Downloading pynvml-11.5.3-py3-none-any.whl.metadata (8.8 kB)
# Collecting rapids-dask-dependency==24.12.* (from dask-cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/rapids-dask-dependency/rapids_dask_dependency-24.12.0-py3-none-any.whl (15 kB)
# Collecting dask-cuda==24.12.* (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/dask-cuda/dask_cuda-24.12.0-py3-none-any.whl (134 kB)
# Collecting joblib>=0.11 (from cuml-cu12==24.12.*)
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting numba>=0.57 (from cuml-cu12==24.12.*)
#   Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.8 kB)
# Collecting nvidia-cublas-cu12 (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-cublas-cu12/nvidia_cublas_cu12-12.8.3.14-py3-none-manylinux_2_27_x86_64.whl (609.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 609.6/609.6 MB 261.0 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cufft-cu12 (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-cufft-cu12/nvidia_cufft_cu12-11.3.3.41-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 247.2 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-curand-cu12 (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-curand-cu12/nvidia_curand_cu12-10.3.9.55-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 263.2 MB/s eta 0:00:00a 0:00:01
# Collecting nvidia-cusolver-cu12 (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-cusolver-cu12/nvidia_cusolver_cu12-11.7.2.55-py3-none-manylinux_2_27_x86_64.whl (260.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 260.4/260.4 MB 254.7 MB/s eta 0:00:0000:0100:01
# Collecting nvidia-cusparse-cu12 (from cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-cusparse-cu12/nvidia_cusparse_cu12-12.5.7.53-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (292.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 292.1/292.1 MB 281.4 MB/s eta 0:00:0000:0100:01
# Collecting scipy>=1.8.0 (from cuml-cu12==24.12.*)
#   Downloading scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Collecting treelite==4.3.0 (from cuml-cu12==24.12.*)
#   Downloading treelite-4.3.0-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting pylibcugraph-cu12==24.12.* (from cugraph-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/pylibcugraph-cu12/pylibcugraph_cu12-24.12.0-cp310-cp310-manylinux_2_28_x86_64.whl (921.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 921.4/921.4 MB 261.4 MB/s eta 0:00:0000:0100:01
# Collecting ucx-py-cu12==0.41.* (from cugraph-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/ucx-py-cu12/ucx_py_cu12-0.41.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 416.2 MB/s eta 0:00:00
# Collecting networkx>=3.2 (from nx-cugraph-cu12==24.12.*)
#   Downloading networkx-3.4.2-py3-none-any.whl.metadata (6.3 kB)
# Collecting geopandas>=1.0.0 (from cuspatial-cu12==24.12.*)
#   Downloading geopandas-1.0.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting libcuspatial-cu12==24.12.* (from cuspatial-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/libcuspatial-cu12/libcuspatial_cu12-24.12.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (17.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.7/17.7 MB 282.6 MB/s eta 0:00:00
# Collecting bokeh>=3.1 (from cuxfilter-cu12==24.12.*)
#   Downloading bokeh-3.6.2-py3-none-any.whl.metadata (12 kB)
# Collecting datashader>=0.15 (from cuxfilter-cu12==24.12.*)
#   Downloading datashader-0.16.3-py2.py3-none-any.whl.metadata (12 kB)
# Collecting holoviews>=1.16.0 (from cuxfilter-cu12==24.12.*)
#   Downloading holoviews-1.20.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting jupyter-server-proxy (from cuxfilter-cu12==24.12.*)
#   Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl.metadata (8.7 kB)
# Collecting panel>=1.0 (from cuxfilter-cu12==24.12.*)
#   Downloading panel-1.6.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/site-packages (from cucim-cu12==24.12.*) (8.1.7)
# Collecting lazy-loader>=0.1 (from cucim-cu12==24.12.*)
#   Downloading lazy_loader-0.4-py3-none-any.whl.metadata (7.6 kB)
# Collecting scikit-image<0.25.0a0,>=0.19.0 (from cucim-cu12==24.12.*)
#   Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (14 kB)
# Collecting distributed-ucxx-cu12==0.41.* (from raft-dask-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/distributed-ucxx-cu12/distributed_ucxx_cu12-0.41.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: zict>=2.0.0 in /usr/local/lib/python3.10/site-packages (from dask-cuda==24.12.*->cuml-cu12==24.12.*) (3.0.0)
# Collecting ucxx-cu12==0.41.* (from distributed-ucxx-cu12==0.41.*->raft-dask-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/ucxx-cu12/ucxx_cu12-0.41.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (841 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 841.7/841.7 kB 438.4 MB/s eta 0:00:00
# Collecting libkvikio-cu12==24.12.* (from libcudf-cu12==24.12.*->cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/libkvikio-cu12/libkvikio_cu12-24.12.1-py3-none-manylinux_2_28_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 414.2 MB/s eta 0:00:00
# Collecting nvidia-nvcomp-cu12==4.1.0.6 (from libcudf-cu12==24.12.*->cudf-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-nvcomp-cu12/nvidia_nvcomp_cu12-4.1.0.6-py3-none-manylinux_2_28_x86_64.whl (28.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.9/28.9 MB 283.2 MB/s eta 0:00:00
# Collecting dask==2024.11.2 (from rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*)
#   Downloading dask-2024.11.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting distributed==2024.11.2 (from rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*)
#   Downloading distributed-2024.11.2-py3-none-any.whl.metadata (3.3 kB)
# Collecting dask-expr==1.1.19 (from rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*)
#   Downloading dask_expr-1.1.19-py3-none-any.whl.metadata (2.6 kB)
# Collecting pynvml<12.0.0a0,>=11.4.1 (from dask-cudf-cu12==24.12.*)
#   Downloading pynvml-11.4.1-py3-none-any.whl.metadata (7.7 kB)
# Collecting libucx-cu12<1.18,>=1.15.0 (from ucx-py-cu12==0.41.*->cugraph-cu12==24.12.*)
#   Downloading libucx_cu12-1.17.0.post1-py3-none-manylinux_2_28_x86_64.whl.metadata (2.9 kB)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/site-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (3.0.0)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/site-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (1.4.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/site-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (6.0)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/site-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (0.12.1)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/site-packages (from dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (7.1.0)
# Requirement already satisfied: jinja2>=2.10.3 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (3.1.3)
# Requirement already satisfied: locket>=1.0.0 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (1.0.0)
# Requirement already satisfied: msgpack>=1.0.2 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (1.0.8)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (6.1.0)
# Requirement already satisfied: sortedcontainers>=2.0.5 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (2.4.0)
# Requirement already satisfied: tblib>=1.6.0 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (3.0.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (6.4.2)
# Requirement already satisfied: urllib3>=1.26.5 in /usr/local/lib/python3.10/site-packages (from distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (2.2.2)
# Collecting libucxx-cu12==0.41.* (from ucxx-cu12==0.41.*->distributed-ucxx-cu12==0.41.*->raft-dask-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/libucxx-cu12/libucxx_cu12-0.41.0-py3-none-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (513 kB)
# Collecting contourpy>=1.2 (from bokeh>=3.1->cuxfilter-cu12==24.12.*)
#   Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: pillow>=7.1.0 in /usr/local/lib/python3.10/site-packages (from bokeh>=3.1->cuxfilter-cu12==24.12.*) (10.3.0)
# Collecting xyzservices>=2021.09.1 (from bokeh>=3.1->cuxfilter-cu12==24.12.*)
#   Downloading xyzservices-2025.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting fastrlock>=0.5 (from cupy-cuda12x>=12.0.0->cudf-cu12==24.12.*)
#   Downloading fastrlock-0.8.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl.metadata (7.7 kB)
# Collecting colorcet (from datashader>=0.15->cuxfilter-cu12==24.12.*)
#   Downloading colorcet-3.1.0-py3-none-any.whl.metadata (6.3 kB)
# Collecting multipledispatch (from datashader>=0.15->cuxfilter-cu12==24.12.*)
#   Downloading multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting param (from datashader>=0.15->cuxfilter-cu12==24.12.*)
#   Downloading param-2.2.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting pyct (from datashader>=0.15->cuxfilter-cu12==24.12.*)
#   Downloading pyct-0.5.0-py2.py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/site-packages (from datashader>=0.15->cuxfilter-cu12==24.12.*) (2.32.3)
# Collecting xarray (from datashader>=0.15->cuxfilter-cu12==24.12.*)
#   Downloading xarray-2025.1.1-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.10/site-packages (from fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (3.9.5)
# Collecting pyogrio>=0.7.2 (from geopandas>=1.0.0->cuspatial-cu12==24.12.*)
#   Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting pyproj>=3.3.0 (from geopandas>=1.0.0->cuspatial-cu12==24.12.*)
#   Downloading pyproj-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas>=1.0.0->cuspatial-cu12==24.12.*)
#   Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting pyviz-comms>=2.1 (from holoviews>=1.16.0->cuxfilter-cu12==24.12.*)
#   Downloading pyviz_comms-3.0.4-py3-none-any.whl.metadata (7.7 kB)
# Collecting llvmlite<0.45,>=0.44.0dev0 (from numba>=0.57->cuml-cu12==24.12.*)
#   Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu12==24.12.*) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu12==24.12.*) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/site-packages (from pandas<2.2.4dev0,>=2.0->cudf-cu12==24.12.*) (2023.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/site-packages (from panel>=1.0->cuxfilter-cu12==24.12.*) (6.0.0)
# Collecting linkify-it-py (from panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading linkify_it_py-2.0.3-py3-none-any.whl.metadata (8.5 kB)
# Collecting markdown (from panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Collecting markdown-it-py (from panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading markdown_it_py-3.0.0-py3-none-any.whl.metadata (6.9 kB)
# Collecting mdit-py-plugins (from panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading mdit_py_plugins-0.4.2-py3-none-any.whl.metadata (2.8 kB)
# Collecting tqdm (from panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting imageio>=2.33 (from scikit-image<0.25.0a0,>=0.19.0->cucim-cu12==24.12.*)
#   Downloading imageio-2.37.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image<0.25.0a0,>=0.19.0->cucim-cu12==24.12.*)
#   Downloading tifffile-2025.1.10-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.14.1)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->cuxfilter-cu12==24.12.*)
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server-proxy->cuxfilter-cu12==24.12.*) (5.9.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cufft-cu12->cuml-cu12==24.12.*)
#   Downloading https://pypi.nvidia.com/nvidia-nvjitlink-cu12/nvidia_nvjitlink_cu12-12.8.61-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.2/39.2 MB 254.5 MB/s eta 0:00:00
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/site-packages (from rich->cudf-cu12==24.12.*) (2.15.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=0.6.0->cugraph-cu12==24.12.*) (4.0.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/site-packages (from jinja2>=2.10.3->distributed==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (2.1.2)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (5.3.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (7.3.0)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (5.8.0)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.16.0)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (26.2.0)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.10/site-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.8.0)
# Collecting mdurl~=0.1 (from markdown-it-py->panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/site-packages (from pyogrio>=0.7.2->geopandas>=1.0.0->cuspatial-cu12==24.12.*) (2024.7.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas<2.2.4dev0,>=2.0->cudf-cu12==24.12.*) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/site-packages (from bleach->panel>=1.0->cuxfilter-cu12==24.12.*) (0.5.1)
# Collecting uc-micro-py (from linkify-it-py->panel>=1.0->cuxfilter-cu12==24.12.*)
#   Downloading uc_micro_py-1.0.3-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/site-packages (from requests->datashader>=0.15->cuxfilter-cu12==24.12.*) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/site-packages (from requests->datashader>=0.15->cuxfilter-cu12==24.12.*) (3.7)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /usr/local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.2.2)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (21.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.10/site-packages (from importlib-metadata>=4.13.0->dask==2024.11.2->rapids-dask-dependency==24.12.*->dask-cudf-cu12==24.12.*) (3.18.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.4)
# Requirement already satisfied: nest-asyncio>=1.5.4 in /usr/local/lib/python3.10/site-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.5.6)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (4.3.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (4.22.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.0.7)
# Requirement already satisfied: referencing in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.35.1)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (4.12.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.2.2)
# Requirement already satisfied: mistune<3,>=2.0.3 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.0.5)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.7.3)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.5.0)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.2.1)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.16.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/site-packages (from terminado>=0.8.3->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.7.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2023.12.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/site-packages (from jsonschema>=4.18.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (0.18.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.3)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.2.0)
# Requirement already satisfied: webcolors>=1.11 in /usr/local/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.13)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (2.22)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->cuxfilter-cu12==24.12.*) (1.2.3)
# Downloading treelite-4.3.0-py3-none-manylinux2014_x86_64.whl (915 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 916.0/916.0 kB 7.3 MB/s eta 0:00:00
# Downloading dask-2024.11.2-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.1 MB/s eta 0:00:00
# Downloading dask_expr-1.1.19-py3-none-any.whl (244 kB)
# Downloading distributed-2024.11.2-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 11.8 MB/s eta 0:00:00
# Downloading bokeh-3.6.2-py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 43.2 MB/s eta 0:00:00
# Downloading cuda_python-12.6.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 65.3 MB/s eta 0:00:00:00:01
# Downloading cupy_cuda12x-13.3.0-cp310-cp310-manylinux2014_x86_64.whl (90.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 MB 112.6 MB/s eta 0:00:0000:0100:01
# Downloading datashader-0.16.3-py2.py3-none-any.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 66.9 MB/s eta 0:00:00:00:01
# Downloading geopandas-1.0.1-py3-none-any.whl (323 kB)
# Downloading holoviews-1.20.0-py3-none-any.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 39.1 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading lazy_loader-0.4-py3-none-any.whl (12 kB)
# Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.1 MB/s eta 0:00:00
# Downloading numba-0.61.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 33.5 MB/s eta 0:00:00
# Downloading numba_cuda-0.0.17.1-py3-none-any.whl (424 kB)
# Downloading nvtx-0.2.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (582 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 582.6/582.6 kB 5.4 MB/s eta 0:00:00
# Downloading panel-1.6.0-py3-none-any.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 78.8 MB/s eta 0:00:00:00:01
# Downloading pyarrow-18.1.0-cp310-cp310-manylinux_2_28_x86_64.whl (40.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.1/40.1 MB 85.4 MB/s eta 0:00:00:00:0100:01
# Downloading pynvml-11.4.1-py3-none-any.whl (46 kB)
# Downloading scikit_image-0.24.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.9/14.9 MB 62.4 MB/s eta 0:00:00:00:01
# Downloading scipy-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (40.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 MB 126.7 MB/s eta 0:00:0000:01
# Downloading cachetools-5.5.1-py3-none-any.whl (9.5 kB)
# Downloading jupyter_server_proxy-4.4.0-py3-none-any.whl (37 kB)
# Downloading pynvjitlink_cu12-0.5.0-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (46.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.2/46.2 MB 87.9 MB/s eta 0:00:00:00:0100:01
# Downloading rich-13.9.4-py3-none-any.whl (242 kB)
# Downloading contourpy-1.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (324 kB)
# Downloading fastrlock-0.8.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_28_x86_64.whl (53 kB)
# Downloading imageio-2.37.0-py3-none-any.whl (315 kB)
# Downloading libucx_cu12-1.17.0.post1-py3-none-manylinux_2_28_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 72.5 MB/s eta 0:00:00:00:01
# Downloading llvmlite-0.44.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.4/42.4 MB 82.1 MB/s eta 0:00:00:00:0100:01
# Downloading markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Downloading param-2.2.0-py3-none-any.whl (119 kB)
# Downloading pyogrio-0.10.0-cp310-cp310-manylinux_2_28_x86_64.whl (23.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.9/23.9 MB 77.9 MB/s eta 0:00:00:00:01
# Downloading pyproj-3.7.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (9.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 38.7 MB/s eta 0:00:00:00:01
# Downloading pyviz_comms-3.0.4-py3-none-any.whl (83 kB)
# Downloading shapely-2.0.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 23.5 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading tifffile-2025.1.10-py3-none-any.whl (227 kB)
# Downloading xyzservices-2025.1.0-py3-none-any.whl (88 kB)
# Downloading colorcet-3.1.0-py3-none-any.whl (260 kB)
# Downloading linkify_it_py-2.0.3-py3-none-any.whl (19 kB)
# Downloading Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading mdit_py_plugins-0.4.2-py3-none-any.whl (55 kB)
# Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Downloading pyct-0.5.0-py2.py3-none-any.whl (15 kB)
# Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading xarray-2025.1.1-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 16.4 MB/s eta 0:00:00
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Downloading uc_micro_py-1.0.3-py3-none-any.whl (6.2 kB)
# Installing collected packages: nvtx, multipledispatch, libkvikio-cu12, fastrlock, cuda-python, xyzservices, uc-micro-py, tqdm, tifffile, simpervisor, shapely, scipy, pyproj, pyogrio, pynvml, pynvjitlink-cu12, pyarrow, param, nvidia-nvjitlink-cu12, nvidia-nvcomp-cu12, nvidia-curand-cu12, nvidia-cublas-cu12, networkx, mdurl, markdown, llvmlite, libucx-cu12, lazy-loader, joblib, imageio, cupy-cuda12x, contourpy, colorcet, cachetools, ucx-py-cu12, treelite, scikit-image, pyviz-comms, pyct, nvidia-cusparse-cu12, nvidia-cufft-cu12, numba, markdown-it-py, linkify-it-py, libucxx-cu12, libcudf-cu12, dask, cuproj-cu12, xarray, rmm-cu12, rich, nvidia-cusolver-cu12, numba-cuda, mdit-py-plugins, libcuspatial-cu12, geopandas, distributed, dask-expr, cucim-cu12, bokeh, ucxx-cu12, rapids-dask-dependency, pylibraft-cu12, pylibcudf-cu12, panel, datashader, pylibcugraph-cu12, holoviews, distributed-ucxx-cu12, dask-cuda, cuvs-cu12, cudf-cu12, raft-dask-cu12, nx-cugraph-cu12, dask-cudf-cu12, cuspatial-cu12, cuml-cu12, cugraph-cu12, jupyter-server-proxy, cuxfilter-cu12
# Successfully installed bokeh-3.6.2 cachetools-5.5.1 colorcet-3.1.0 contourpy-1.3.1 cucim-cu12-24.12.0 cuda-python-12.6.0 cudf-cu12-24.12.0 cugraph-cu12-24.12.0 cuml-cu12-24.12.0 cuproj-cu12-24.12.0 cupy-cuda12x-13.3.0 cuspatial-cu12-24.12.0 cuvs-cu12-24.12.0 cuxfilter-cu12-24.12.0 dask-2024.11.2 dask-cuda-24.12.0 dask-cudf-cu12-24.12.0 dask-expr-1.1.19 datashader-0.16.3 distributed-2024.11.2 distributed-ucxx-cu12-0.41.0 fastrlock-0.8.3 geopandas-1.0.1 holoviews-1.20.0 imageio-2.37.0 joblib-1.4.2 jupyter-server-proxy-4.4.0 lazy-loader-0.4 libcudf-cu12-24.12.0 libcuspatial-cu12-24.12.0 libkvikio-cu12-24.12.1 libucx-cu12-1.17.0.post1 libucxx-cu12-0.41.0 linkify-it-py-2.0.3 llvmlite-0.44.0 markdown-3.7 markdown-it-py-3.0.0 mdit-py-plugins-0.4.2 mdurl-0.1.2 multipledispatch-1.0.0 networkx-3.4.2 numba-0.61.0 numba-cuda-0.0.17.1 nvidia-cublas-cu12-12.8.3.14 nvidia-cufft-cu12-11.3.3.41 nvidia-curand-cu12-10.3.9.55 nvidia-cusolver-cu12-11.7.2.55 nvidia-cusparse-cu12-12.5.7.53 nvidia-nvcomp-cu12-4.1.0.6 nvidia-nvjitlink-cu12-12.8.61 nvtx-0.2.10 nx-cugraph-cu12-24.12.0 panel-1.6.0 param-2.2.0 pyarrow-18.1.0 pyct-0.5.0 pylibcudf-cu12-24.12.0 pylibcugraph-cu12-24.12.0 pylibraft-cu12-24.12.0 pynvjitlink-cu12-0.5.0 pynvml-11.4.1 pyogrio-0.10.0 pyproj-3.7.0 pyviz-comms-3.0.4 raft-dask-cu12-24.12.0 rapids-dask-dependency-24.12.0 rich-13.9.4 rmm-cu12-24.12.1 scikit-image-0.24.0 scipy-1.15.1 shapely-2.0.6 simpervisor-1.0.0 tifffile-2025.1.10 tqdm-4.67.1 treelite-4.3.0 uc-micro-py-1.0.3 ucx-py-cu12-0.41.0 ucxx-cu12-0.41.0 xarray-2025.1.1 xyzservices-2025.1.0

# %%
# !./dataprep.sh
# Out:
# --2025-01-28 00:03:49--  https://sparse.tamu.edu/MM/DIMACS10/preferentialAttachment.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 3.33.193.101, 99.83.183.127, 15.197.246.237, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|3.33.193.101|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/preferentialAttachment.tar.gz [following]
# --2025-01-28 00:03:49--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/preferentialAttachment.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 3.5.133.180, 52.219.94.32, 52.219.109.192, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|3.5.133.180|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2027782 (1.9M) [application/x-tar]
# Saving to: ‘preferentialAttachment.tar.gz’
#
# preferentialAttachm 100%[===================>]   1.93M  --.-KB/s    in 0.003s
#
# 2025-01-28 00:03:50 (619 MB/s) - ‘preferentialAttachment.tar.gz’ saved [2027782/2027782]
#
# --2025-01-28 00:03:50--  https://sparse.tamu.edu/MM/DIMACS10/caidaRouterLevel.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 3.33.193.101, 15.197.246.237, 52.223.46.195, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|3.33.193.101|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/caidaRouterLevel.tar.gz [following]
# --2025-01-28 00:03:50--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/caidaRouterLevel.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 52.219.178.176, 16.12.65.160, 3.5.132.44, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|52.219.178.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2418742 (2.3M) [application/x-tar]
# Saving to: ‘caidaRouterLevel.tar.gz’
#
# caidaRouterLevel.ta 100%[===================>]   2.31M  --.-KB/s    in 0.05s
#
# 2025-01-28 00:03:50 (51.1 MB/s) - ‘caidaRouterLevel.tar.gz’ saved [2418742/2418742]
#
# --2025-01-28 00:03:50--  https://sparse.tamu.edu/MM/DIMACS10/coAuthorsDBLP.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 52.223.46.195, 15.197.246.237, 3.33.193.101, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|52.223.46.195|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/coAuthorsDBLP.tar.gz [following]
# --2025-01-28 00:03:50--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/coAuthorsDBLP.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 3.5.133.180, 52.219.94.32, 52.219.109.192, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|3.5.133.180|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3206075 (3.1M) [application/x-tar]
# Saving to: ‘coAuthorsDBLP.tar.gz’
#
# coAuthorsDBLP.tar.g 100%[===================>]   3.06M  --.-KB/s    in 0.008s
#
# 2025-01-28 00:03:50 (361 MB/s) - ‘coAuthorsDBLP.tar.gz’ saved [3206075/3206075]
#
# --2025-01-28 00:03:50--  https://sparse.tamu.edu/MM/LAW/dblp-2010.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 52.223.46.195, 99.83.183.127, 3.33.193.101, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|52.223.46.195|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/LAW/dblp-2010.tar.gz [following]
# --2025-01-28 00:03:51--  http://sparse-files.engr.tamu.edu/MM/LAW/dblp-2010.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 52.219.229.176, 3.5.133.149, 3.5.133.180, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|52.219.229.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2235407 (2.1M) [application/x-tar]
# Saving to: ‘dblp-2010.tar.gz’
#
# dblp-2010.tar.gz    100%[===================>]   2.13M  --.-KB/s    in 0.05s
#
# 2025-01-28 00:03:51 (45.4 MB/s) - ‘dblp-2010.tar.gz’ saved [2235407/2235407]
#
# --2025-01-28 00:03:51--  https://sparse.tamu.edu/MM/DIMACS10/citationCiteseer.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 3.33.193.101, 99.83.183.127, 15.197.246.237, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|3.33.193.101|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/citationCiteseer.tar.gz [following]
# --2025-01-28 00:03:51--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/citationCiteseer.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 52.219.178.176, 16.12.65.160, 52.219.106.240, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|52.219.178.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 5082095 (4.8M) [application/x-tar]
# Saving to: ‘citationCiteseer.tar.gz’
#
# citationCiteseer.ta 100%[===================>]   4.85M  --.-KB/s    in 0.1s
#
# 2025-01-28 00:03:51 (49.3 MB/s) - ‘citationCiteseer.tar.gz’ saved [5082095/5082095]
#
# --2025-01-28 00:03:51--  https://sparse.tamu.edu/MM/DIMACS10/coPapersDBLP.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 15.197.246.237, 99.83.183.127, 3.33.193.101, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|15.197.246.237|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/coPapersDBLP.tar.gz [following]
# --2025-01-28 00:03:51--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/coPapersDBLP.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 52.219.178.176, 3.5.132.44, 3.5.130.160, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|52.219.178.176|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36298718 (35M) [application/x-tar]
# Saving to: ‘coPapersDBLP.tar.gz’
#
# coPapersDBLP.tar.gz 100%[===================>]  34.62M  56.5MB/s    in 0.6s
#
# 2025-01-28 00:03:52 (56.5 MB/s) - ‘coPapersDBLP.tar.gz’ saved [36298718/36298718]
#
# --2025-01-28 00:03:52--  https://sparse.tamu.edu/MM/DIMACS10/coPapersCiteseer.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 3.33.193.101, 52.223.46.195, 15.197.246.237, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|3.33.193.101|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/DIMACS10/coPapersCiteseer.tar.gz [following]
# --2025-01-28 00:03:52--  http://sparse-files.engr.tamu.edu/MM/DIMACS10/coPapersCiteseer.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 3.5.133.180, 52.219.232.80, 52.219.229.176, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|3.5.133.180|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36652888 (35M) [application/x-tar]
# Saving to: ‘coPapersCiteseer.tar.gz’
#
# coPapersCiteseer.ta 100%[===================>]  34.95M  53.0MB/s    in 0.7s
#
# 2025-01-28 00:03:53 (53.0 MB/s) - ‘coPapersCiteseer.tar.gz’ saved [36652888/36652888]
#
# --2025-01-28 00:03:53--  https://sparse.tamu.edu/MM/SNAP/as-Skitter.tar.gz
# Resolving sparse.tamu.edu (sparse.tamu.edu)... 99.83.183.127, 15.197.246.237, 3.33.193.101, ...
# Connecting to sparse.tamu.edu (sparse.tamu.edu)|99.83.183.127|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: http://sparse-files.engr.tamu.edu/MM/SNAP/as-Skitter.tar.gz [following]
# --2025-01-28 00:03:54--  http://sparse-files.engr.tamu.edu/MM/SNAP/as-Skitter.tar.gz
# Resolving sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)... 3.5.133.180, 16.12.65.216, 52.219.94.32, ...
# Connecting to sparse-files.engr.tamu.edu (sparse-files.engr.tamu.edu)|3.5.133.180|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 33172905 (32M) [application/x-tar]
# Saving to: ‘as-Skitter.tar.gz’
#
# as-Skitter.tar.gz   100%[===================>]  31.64M  72.5MB/s    in 0.4s
#
# 2025-01-28 00:03:54 (72.5 MB/s) - ‘as-Skitter.tar.gz’ saved [33172905/33172905]
#
# preferentialAttachment/preferentialAttachment.mtx
# caidaRouterLevel/caidaRouterLevel.mtx
# coAuthorsDBLP/coAuthorsDBLP.mtx
# dblp-2010/dblp-2010.mtx
# citationCiteseer/citationCiteseer.mtx
# coPapersDBLP/coPapersDBLP.mtx
# coPapersCiteseer/coPapersCiteseer.mtx
# as-Skitter/as-Skitter.mtx
